# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

indicePrecosComerciais = pd.read_csv("dados/business-price-indexes-march-2020-quarter-csv.csv",sep=",", encoding="ISO-8859-1", low_memory=False)
indicePrecosComerciais.columns.values
colunasSelecionadas = ['Series_reference', 'Period', 
                       'Data_value', 'STATUS', 'UNITS',
                       'Subject', 'Group']
dataFrameResumido = indicePrecosComerciais.filter(items=colunasSelecionadas)
dataFrameResumido.head()
# Out:
#   Series_reference   Period  Data_value STATUS  UNITS  \
# 0       CEPQ.S2371  1996.12       899.0  FINAL  Index
# 1       CEPQ.S2371  1997.03       884.0  FINAL  Index
# 2       CEPQ.S2371  1997.06       925.0  FINAL  Index
# 3       CEPQ.S2371  1997.09       932.0  FINAL  Index
# 4       CEPQ.S2371  1997.12       929.0  FINAL  Index
#
#                            Subject  \
# 0  Capital Goods Price Index - CEP
# 1  Capital Goods Price Index - CEP
# 2  Capital Goods Price Index - CEP
# 3  Capital Goods Price Index - CEP
# 4  Capital Goods Price Index - CEP
#
#                                                Group
# 0  Price Index by Item - Plant, Machinery and Equ...
# 1  Price Index by Item - Plant, Machinery and Equ...
# 2  Price Index by Item - Plant, Machinery and Equ...
# 3  Price Index by Item - Plant, Machinery and Equ...
# 4  Price Index by Item - Plant, Machinery and Equ...

# %%
dataFrameResumido['level'] = ['high' if value > 900 else 'low' for value in dataFrameResumido['Data_value']]
dataFrameResumido.where(dataFrameResumido.Period > 1996.12).dropna().head()
# Out:
#   Series_reference   Period  Data_value STATUS  UNITS  \
# 1       CEPQ.S2371  1997.03       884.0  FINAL  Index
# 2       CEPQ.S2371  1997.06       925.0  FINAL  Index
# 3       CEPQ.S2371  1997.09       932.0  FINAL  Index
# 4       CEPQ.S2371  1997.12       929.0  FINAL  Index
# 5       CEPQ.S2371  1998.03       940.0  FINAL  Index
#
#                            Subject  \
# 1  Capital Goods Price Index - CEP
# 2  Capital Goods Price Index - CEP
# 3  Capital Goods Price Index - CEP
# 4  Capital Goods Price Index - CEP
# 5  Capital Goods Price Index - CEP
#
#                                                Group level
# 1  Price Index by Item - Plant, Machinery and Equ...   low
# 2  Price Index by Item - Plant, Machinery and Equ...  high
# 3  Price Index by Item - Plant, Machinery and Equ...  high
# 4  Price Index by Item - Plant, Machinery and Equ...  high
# 5  Price Index by Item - Plant, Machinery and Equ...  high

# %%
fig, ax = plt.subplots(figsize=(20,5))
colunas = ['Series_reference', 'Subject', 'Data_value']
dataFrameResumido.filter(items=colunas)\
.groupby(['Series_reference', 'Subject']).mean()\
.sort_values(by='Data_value', ascending=False)\
.dropna()\
.unstack().plot(ax=ax)
